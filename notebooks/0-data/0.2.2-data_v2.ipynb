# %% [markdown]
# ## Libraries

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Read data

# %%
df = pd.read_csv('../../data/processed/processed_data.csv')

# %%
## Final processing
# Drop file columns
df.drop(columns='file',inplace=True)
# divide by sexo and drop sex column
data_m = df[df.sexo==1].drop(columns="sexo")
data_f = df[df.sexo==2].drop(columns="sexo")

# Normalizado
mean_m = data_m.mean()
data_m.to_csv('../../data/interim/mean_m.csv', index=False)
std_m = data_m.std()
data_m.to_csv('../../data/interim/std_m.csv', index=False)

mean_f = data_f.mean()
data_m.to_csv('../../data/interim/mean_f.csv', index=False)
std_f = data_f.std()
data_m.to_csv('../../data/interim/std_f.csv', index=False)


for columna in data_m.columns:
    data_m[columna] = (data_m[columna] - data_m[columna].mean()) / data_m[columna].std()
    data_f[columna] = (data_f[columna] - data_f[columna].mean()) / data_f[columna].std()

# %%
features = data_m.columns.drop(['masa_muscular','masa_piel',
       'masa_adiposa', 'masa_residual', 'masa_osea'])

# %%
for feature in features:
    for power in [2]:
        new_f = feature +'_' +str(power)
        data_m[new_f] = data_m[feature]**power
        data_f[new_f] = data_f[feature]**power

# %%
data_m
# Out:
#          edad      peso     talla  per_brazo_rel  per_brazo_ten  \
# 1   -1.036390 -1.129647 -1.041523      -0.245085      -0.364953
# 2   -0.425749 -1.106688  0.645564      -1.516202      -2.004565
# 4    0.033609  1.495342 -1.424952       3.133412       2.974995
# 5   -0.378883  0.576979 -0.581408       0.357024       0.788847
# 6    0.297577 -0.326079  0.338821       0.055969       0.667394
# ..        ...       ...       ...            ...            ...
# 305 -1.340331 -2.178113 -0.734780      -1.783806      -1.609843
# 309 -0.919913 -1.091382 -1.041523      -0.010932      -0.243501
# 311  0.968523  0.148409 -0.734780      -0.077832       0.120857
# 313  1.273154  1.495342 -1.194895       1.795393       1.760468
# 314 -0.440568 -0.004652  1.028993      -0.546139      -0.516769
#
#      per_antebrazo  per_torax  per_cintura  per_cadera  per_muslo_max  ...  \
# 1        -0.791100  -0.661568    -1.015423   -1.182268      -1.117874  ...
# 2        -1.668563  -2.015216    -1.005378   -0.498441      -1.117874  ...
# 4         2.718753   1.299323     1.355101    1.642233       2.023883  ...
# 5         0.757365   0.413759     0.551533    0.675956       0.750198  ...
# 6         0.602518  -0.092277    -0.000919   -0.394381      -0.948049  ...
# ..             ...        ...          ...         ...            ...  ...
# 305      -1.823410  -2.154376    -2.150461   -2.371532      -2.285419  ...
# 309      -0.326561  -0.408550    -0.854709   -1.122805      -0.948049  ...
# 311       0.137979   0.666777     0.551533   -0.290320      -0.098926  ...
# 313       1.531597   1.742105     2.048177    1.478709       1.068619  ...
# 314      -0.481407  -0.079626    -0.704040   -0.275454       0.240724  ...
#
#       talla_2  per_brazo_rel_2  per_brazo_ten_2  per_antebrazo_2  per_torax_2  \
# 1    1.084770         0.060067         0.133191         0.625839     0.437672
# 2    0.416753         2.298869         4.018279         2.784104     4.061094
# 4    2.030488         9.818270         8.850597         7.391618     1.688240
# 5    0.338036         0.127466         0.622280         0.573601     0.171197
# 6    0.114800         0.003133         0.445415         0.363028     0.008515
# ..        ...              ...              ...              ...          ...
# 305  0.539902         3.181964         2.591596         3.324824     4.641334
# 309  1.084770         0.000119         0.059293         0.106642     0.166913
# 311  0.539902         0.006058         0.014606         0.019038     0.444592
# 313  1.427773         3.223437         3.099249         2.345789     3.034929
# 314  1.058826         0.298268         0.267050         0.231753     0.006340
#
#      per_cintura_2  per_cadera_2  per_muslo_max_2  per_muslo_medial_2  \
# 1     1.031083e+00      1.397758         1.249642            2.356687
# 2     1.010785e+00      0.248444         1.249642            2.022671
# 4     1.836298e+00      2.696930         4.096102            4.136647
# 5     3.041890e-01      0.456917         0.562797            0.401159
# 6     8.447684e-07      0.155536         0.898797            0.269004
# ..             ...           ...              ...                 ...
# 305   4.624484e+00      5.624162         5.223138            6.861315
# 309   7.305279e-01      1.260691         0.898797            0.814804
# 311   3.041890e-01      0.084286         0.009786            0.062182
# 313   4.195030e+00      2.186581         1.141947            0.989610
# 314   4.956729e-01      0.075875         0.057948            0.004713
#
#      per_pantorrilla_2
# 1             1.499021
# 2             0.110752
# 4             2.827279
# 5             2.200264
# 6             0.580735
# ..                 ...
# 305           7.707868
# 309           1.341669
# 311           0.000007
# 313           2.400546
# 314           0.110752
#
# [153 rows x 29 columns]

# %%
data_m.to_csv('../../data/processed/data_m_v2.csv', index=False)
data_f.to_csv('../../data/processed/data_f_v2.csv', index=False)
