# %% [markdown]
# # Exploratory analysis

# %% [markdown]
# ## Libraries

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Leyendo data

# %%
files = os.listdir('../../data/raw')
sheet = "Proc datos brutos"
os.path.join('../../data/raw',files[0])
# Out:
# '../../data/raw/ANTROPOMETRIA (24).xls'

# %%
df = pd.read_excel(io=os.path.join('../../data/raw',files[0]), sheet_name=sheet)
#generales
sexo = df.iloc[0,8]
edad = df.iloc[1,8]
peso = df.iloc[4,1]
talla = df.iloc[5,1]
#perimetros
per_brazo_rel = df.iloc[16,1]
per_brazo_ten = df.iloc[17,1]
per_antebrazo = df.iloc[18,1]
per_torax = df.iloc[19,1]
per_cintura = df.iloc[20,1]
per_cadera = df.iloc[21,1]
per_muslo_max = df.iloc[22,1]
per_muslo_medial = df.iloc[23,1]
per_pantorrilla = df.iloc[24,1]
#masas resultado
masa_piel = df.iloc[45,1]
masa_adiposa = df.iloc[50,1]
masa_muscular = df.iloc[60,1]
masa_residual = df.iloc[66,1]
masa_osea = df.iloc[76,1]

"""
print(f'sexo:{sexo}')
print(f'edad:{edad}')
print(f'peso:{peso}')
print(f'talla:{talla}')
print(f'per_brazo_rel:{per_brazo_rel}')
print(f'per_brazo_ten:{per_brazo_ten}')
print(f'per_antebrazo:{per_antebrazo}')
print(f'per_torax:{per_torax}')
print(f'per_cintura:{per_cintura}')
print(f'per_cadera:{per_cadera}')
print(f'per_muslo_max:{per_muslo_max}')
print(f'per_muslo_medial:{per_muslo_medial}')
print(f'per_pantorrilla:{per_pantorrilla}')
"""
print(f'masa_piel:{masa_piel}')
print(f'masa_adiposa:{masa_adiposa}')
print(f'masa_muscular:{masa_muscular}')
print(f'masa_residual:{masa_residual}')
print(f'masa_osea:{masa_osea}')
# Out:
# masa_piel:3.7502019137098657
# masa_adiposa:24.924776179468072
# masa_muscular:32.163791327554286
# masa_residual:8.108961821122866
# masa_osea:9.331516729627333

# %% [markdown]
# ## Extrayendo data

# %%
columnas = ["file","sexo","edad","peso","talla","per_brazo_rel","per_brazo_ten","per_antebrazo",
"per_torax","per_cintura","per_cadera","per_muslo_max","per_muslo_medial",
"per_pantorrilla","masa_piel","masa_adiposa","masa_muscular","masa_residual",
"masa_osea"]
df = pd.DataFrame(columns=columnas)
df
# Out:
# Empty DataFrame
# Columns: [file, sexo, edad, peso, talla, per_brazo_rel, per_brazo_ten, per_antebrazo, per_torax, per_cintura, per_cadera, per_muslo_max, per_muslo_medial, per_pantorrilla, masa_piel, masa_adiposa, masa_muscular, masa_residual, masa_osea]
# Index: []

# %%
sheet = "Proc datos brutos"
for index,file in enumerate(files):
    try:
        temp_df = pd.read_excel(io=os.path.join('../../data/raw',file), sheet_name=sheet)
        #generales
        sexo = temp_df.iloc[0,8]
        edad = temp_df.iloc[1,8]
        peso = temp_df.iloc[4,1]
        talla = temp_df.iloc[5,1]
        #perimetros
        per_brazo_rel = temp_df.iloc[16,1]
        per_brazo_ten = temp_df.iloc[17,1]
        per_antebrazo = temp_df.iloc[18,1]
        per_torax = temp_df.iloc[19,1]
        per_cintura = temp_df.iloc[20,1]
        per_cadera = temp_df.iloc[21,1]
        per_muslo_max = temp_df.iloc[22,1]
        per_muslo_medial = temp_df.iloc[23,1]
        per_pantorrilla = temp_df.iloc[24,1]
        #masas resultado
        masa_piel = temp_df.iloc[45,1]
        masa_adiposa = temp_df.iloc[50,1]
        masa_muscular = temp_df.iloc[60,1]
        masa_residual = temp_df.iloc[66,1]
        masa_osea = temp_df.iloc[76,1]
        
        lista = [file,sexo,edad,peso,talla,per_brazo_rel,per_brazo_ten,per_antebrazo,per_torax,
                per_cintura,per_cadera,per_muslo_max,per_muslo_medial,per_pantorrilla,
                masa_piel,masa_adiposa,masa_muscular,masa_residual,masa_osea
                ]
        df.loc[index] = lista
    except:
        print('error')
        pass
# Out:
# error
# error
# error
# error
# error
# error
# error
# error

# %%
df.reset_index(inplace=True, drop=True)
df
# Out:
#                                     file  sexo       edad   peso  talla  \
# 0                 ANTROPOMETRIA (24).xls     2  32.783025   75.8  160.0
# 1            ANTROPOMODELO 28-4-2021.xls     1  20.240931   66.7  165.0
# 2         ANTROPOMODELO 3-2-2021 (2).xls     1  25.092402   67.0  176.0
# 3           ANTROPOMODELO COMUN (11).xls     2  24.605065   52.2  154.0
# 4                 ANTROPOMETRIA (18).xls     1  28.741958  101.0  162.5
# ..                                   ...   ...        ...    ...    ...
# 313      ANTROPOMETRIA - 16-3-22 (2).xls     2  23.444216   91.0  167.0
# 314           ANTROPOMODELO 5-5-2021.xls     1  38.590007  101.0  164.0
# 315  ANTROPOMODELO CONTROL 16-6-2021.xls     1  24.974675   81.4  178.5
# 316               ANTROPOMODELO (15).xls     2  46.198494   65.2  171.0
# 317               ANTROPOMODELO (11).xls     2  44.161533  106.0  156.0
#
#      per_brazo_rel  per_brazo_ten  per_antebrazo  per_torax  per_cintura  \
# ...

# %% [markdown]
# ## Limpiando data

# %%
df.loc[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [file, sexo, edad, peso, talla, per_brazo_rel, per_brazo_ten, per_antebrazo, per_torax, per_cintura, per_cadera, per_muslo_max, per_muslo_medial, per_pantorrilla, masa_piel, masa_adiposa, masa_muscular, masa_residual, masa_osea]
# Index: []

# %%
try:
    df=df.drop(df.loc[df.edad<10].index,0)
except:
    pass
df.loc[df.edad<10]
# Out:
# /tmp/ipykernel_19726/846067499.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df=df.drop(df.loc[df.edad<10].index,0)
# Empty DataFrame
# Columns: [file, sexo, edad, peso, talla, per_brazo_rel, per_brazo_ten, per_antebrazo, per_torax, per_cintura, per_cadera, per_muslo_max, per_muslo_medial, per_pantorrilla, masa_piel, masa_adiposa, masa_muscular, masa_residual, masa_osea]
# Index: []

# %%
data_types_dict = {'sexo':int, 'talla':float, 'per_brazo_ten': float}
df = df.astype(data_types_dict)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317 entries, 0 to 317
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   file              317 non-null    object
#  1   sexo              317 non-null    int64
#  2   edad              317 non-null    float64
#  3   peso              317 non-null    float64
#  4   talla             317 non-null    float64
#  5   per_brazo_rel     317 non-null    float64
#  6   per_brazo_ten     317 non-null    float64
#  7   per_antebrazo     317 non-null    float64
#  8   per_torax         317 non-null    float64
#  9   per_cintura       317 non-null    float64
#  10  per_cadera        317 non-null    float64
#  11  per_muslo_max     317 non-null    float64
#  12  per_muslo_medial  317 non-null    float64
#  13  per_pantorrilla   317 non-null    float64
#  14  masa_piel         317 non-null    float64
#  15  masa_adiposa      317 non-null    float64
# ...

# %% [markdown]
# ## Guardar data

# %%
df.to_csv('../../data/processed/processed_data.csv', index=False)

# %%
df
# Out:
#                                     file  sexo       edad   peso  talla  \
# 0                 ANTROPOMETRIA (24).xls     2  32.783025   75.8  160.0
# 1            ANTROPOMODELO 28-4-2021.xls     1  20.240931   66.7  165.0
# 2         ANTROPOMODELO 3-2-2021 (2).xls     1  25.092402   67.0  176.0
# 3           ANTROPOMODELO COMUN (11).xls     2  24.605065   52.2  154.0
# 4                 ANTROPOMETRIA (18).xls     1  28.741958  101.0  162.5
# ..                                   ...   ...        ...    ...    ...
# 313      ANTROPOMETRIA - 16-3-22 (2).xls     2  23.444216   91.0  167.0
# 314           ANTROPOMODELO 5-5-2021.xls     1  38.590007  101.0  164.0
# 315  ANTROPOMODELO CONTROL 16-6-2021.xls     1  24.974675   81.4  178.5
# 316               ANTROPOMODELO (15).xls     2  46.198494   65.2  171.0
# 317               ANTROPOMODELO (11).xls     2  44.161533  106.0  156.0
#
#      per_brazo_rel  per_brazo_ten  per_antebrazo  per_torax  per_cintura  \
# ...

# %% [markdown]
# ## Visualizando data

# %%
for column in df.columns:
    if column != 'file':
        plt.figure();
        #sns.histplot(data=df,x=column, hue='sexo', palette='inferno');  
        sns.kdeplot(data=df,x=column, shade=True, hue='sexo', palette=['b','r'])
# Out:
# /home/giampa95/anaconda3/envs/ds/lib/python3.9/site-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
for column in df.columns:
    if column not in ['file',"masa_piel","masa_adiposa","masa_muscular","masa_residual","masa_osea"]:
        plt.figure();
        sns.catplot(data=df, y=column, x='sexo',kind='box', palette=['b','r'])
# Out:
# /tmp/ipykernel_19726/113303657.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure();

# %%
for column in df.columns:
    if column not in ['file',"masa_piel","masa_adiposa","masa_muscular","masa_residual","masa_osea"]:
        plt.figure();
        sns.scatterplot(data=df, x=column, y='masa_residual', hue='sexo', palette=['b','r'])

# %% [markdown]
# ## CORR

# %%
corr = df.corr().sort_values(by="masa_piel",ascending=False).round(2)
print(corr["masa_piel"])
# Out:
# masa_piel           1.00
# peso                0.96
# masa_osea           0.90
# per_torax           0.86
# per_antebrazo       0.86
# masa_residual       0.86
# masa_muscular       0.84
# per_muslo_medial    0.84
# per_brazo_rel       0.83
# per_pantorrilla     0.82
# per_brazo_ten       0.82
# per_cintura         0.80
# talla               0.74
# per_muslo_max       0.74
# per_cadera          0.73
# masa_adiposa        0.59
# edad                0.10
# sexo               -0.55
# Name: masa_piel, dtype: float64

# %%
corr = df.corr().sort_values(by="masa_adiposa",ascending=False).round(2)
print(corr["masa_adiposa"])
# Out:
# masa_adiposa        1.00
# per_cadera          0.78
# per_muslo_max       0.75
# per_pantorrilla     0.66
# peso                0.65
# per_muslo_medial    0.64
# per_brazo_rel       0.60
# masa_piel           0.59
# per_cintura         0.57
# masa_osea           0.49
# masa_residual       0.47
# per_torax           0.45
# per_brazo_ten       0.45
# per_antebrazo       0.43
# talla               0.21
# masa_muscular       0.19
# edad                0.14
# sexo                0.09
# Name: masa_adiposa, dtype: float64

# %%
corr = df.corr().sort_values(by="masa_muscular",ascending=False).round(2)
print(corr["masa_muscular"])
# Out:
# masa_muscular       1.00
# per_torax           0.91
# per_antebrazo       0.90
# per_brazo_ten       0.88
# masa_residual       0.85
# masa_piel           0.84
# peso                0.84
# masa_osea           0.84
# per_brazo_rel       0.80
# per_cintura         0.77
# per_muslo_medial    0.72
# per_pantorrilla     0.69
# talla               0.61
# per_muslo_max       0.53
# per_cadera          0.47
# masa_adiposa        0.19
# edad                0.11
# sexo               -0.77
# Name: masa_muscular, dtype: float64

# %%
corr = df.corr().sort_values(by="masa_residual",ascending=False).round(2)
print(corr["masa_residual"])
# Out:
# masa_residual       1.00
# per_cintura         0.95
# per_torax           0.93
# peso                0.92
# per_antebrazo       0.88
# masa_osea           0.87
# per_brazo_ten       0.86
# masa_piel           0.86
# masa_muscular       0.85
# per_brazo_rel       0.85
# per_pantorrilla     0.80
# per_muslo_medial    0.76
# per_cadera          0.67
# per_muslo_max       0.64
# masa_adiposa        0.47
# talla               0.42
# edad                0.33
# sexo               -0.52
# Name: masa_residual, dtype: float64

# %%
corr = df.corr().sort_values(by="masa_osea",ascending=False).round(2)
print(corr["masa_osea"])
# Out:
# masa_osea           1.00
# peso                0.91
# masa_piel           0.90
# masa_residual       0.87
# per_antebrazo       0.86
# per_torax           0.84
# masa_muscular       0.84
# per_cintura         0.83
# per_pantorrilla     0.82
# per_brazo_ten       0.82
# per_brazo_rel       0.80
# per_muslo_medial    0.77
# per_cadera          0.66
# per_muslo_max       0.65
# talla               0.60
# masa_adiposa        0.49
# edad                0.18
# sexo               -0.58
# Name: masa_osea, dtype: float64
